# %% [markdown]
# # Theory Questions

# %% [markdown]
# 1. What is the difference between interpreted and compiled languages ?
#
#     - interpretd : An interpreted language is executed line by line by an interpreter at runtime.
#
#     - ex: python ,javascript, php
#
#
#     - compiled: A compiled language is first converted completely into machine code by a compiler before execution
#
#     - example: c,c++,java
#
#     - source code --> complier --> machine code --> output

# %% [markdown]
# 2. What is exception handling in Python?
#
#
#     -  exception hnadling in python is to handle runtime error so the flow of program does not break
#
#      - in simple words, it helps your program to deal with error by its own instead of crashing
#
#      - it consists try , except and finally block
#
#      - examples are:ZeroDivisionError,ValueError, TypeError, FileNotFoundError

# %% [markdown]
# 3. What is the purpose of the finally block in exception handling?
#
#
#    - the finally block in python is used to execute code that must run no matter what , whether exception occurs or
#
#
#    - so the finally block always run even the exception runs or not

# %% [markdown]
# 4. What is logging in Python?
#
#     - logging in python is a technique used to record messages about programs such as errors,warnings, informational messages for debugging and monitoring purpose
#
#
#     - instead of use print statement we use logging that provides a systematic and professional ways to track what the program is doing
#
#     - there are different level of logging in python
#
#     - DEBUG
#     - INFO
#     - WARNING
#     - ERROR
#     - CRITICAL

# %% [markdown]
# 5.  What is the significance of the __del__ method in Python?
#
#
#     - The __del__ method in Python is a destructor method.
#
#     - It is automatically called when an object is about to be destroyed or removed from memory.

# %% [markdown]
# 6. What is the difference between import and from ... import in Python?
#
#    - the import statement imports an entire module and requires the module name to access its members whereas the "from..import statement import specific components from a module and allows direct access without using the module name

# %% [markdown]
# 7.  How can you handle multiple exceptions in Python?
#
#     -  multiple exception in python can be handled bu using multiple except blocks or by specifying multiple exceptions in a single except block. This allows the program to handle different runtime errors smoothly without crashing.

# %% [markdown]
# 8. What is the purpose of the with statement when handling files in Python?
#
#
#      - the with statement in python is used to open the files safely and automatically manage resources
#
#      - its main purpose is to ensure the file is properly closed after use even if an error occurs

# %% [markdown]
# 9. What is the difference between multithreading and multiprocessing?
#
#
#     - multithreading : when a single process runs on multiple threads sharing the same memory is called multithreading
#
#     - multiprocessing : when multiple processes are executed using multiple processors (or CPU cores), each with separate memory space then it is called multiprocessing.

# %% [markdown]
# 10.  What are the advantages of using logging in a program?
#
#
#      - helps in debugging
#      - helps to better error tracking
#      -  improve program monitoring
#
#      - Helps in maintenance : make it easier to maintain and update large applications

# %% [markdown]
# 11. What is memory management in Python?
#
#     - memory management in python is a process by which python allocates , uses and free memeory automatically during program execution
#
#
#     - python handles memeory management on its own so the programmer does not need to manually allocate and deallocate memeory

# %% [markdown]
# 12. What are the basic steps involved in exception handling in Python?
#
#    - step 1:place a risky Code in **try** Block
#
#    - step 2: handle error using **except** block
#
#    - step 3: execute **else** block (it is not any necessary that you should have an else block it is an optional)
#
#    - step 4. execute **finally** block

# %% [markdown]
# 13.  Why is memory management important in Python?
#
#
#       - memory management in Python is important because it automatically allocates and deallocates memory, prevents memory leaks, improves performance, and ensures stable execution of programs.

# %% [markdown]
# 14.  What is the role of try and except in exception handling?
#
#      - The "try" block is used to write code that may cause an exception, while the "except" block is used to catch and handle the exception, preventing the program from crashing.

# %% [markdown]
# 15.  How does Python's garbage collection system work?
#
#      - Python's garbage collection system automatically manages memory during program execution. It mainly works using reference counting and garbage collection. Every object in Python keeps a count of how many references point to it. When this reference count becomes zero, the object is automatically removed from memory. Python also detects and removes unused or unreachable objects, including those involved in circular references. This process helps free unused memory, prevents memory leaks, and ensures efficient use of memory without programmer intervention.

# %% [markdown]
# 16.  What is the purpose of the else block in exception handling?
#
#       - The else block in exception handling is executed when the try block runs successfully without any exception. It is used to write normal execution code separately from error-handling code, improving program clarity.

# %% [markdown]
# 17.  What are the common logging levels in Python?
#
#      - Python provides logging levels such as DEBUG, INFO, WARNING, ERROR, and CRITICAL to represent different levels of message severity. These levels help in monitoring program execution and debugging errors effectively.

# %% [markdown]
# 18. What is the difference between os.fork() and multiprocessing in Python?
#
#      - os.fork() is a low-level system call used to create a child process by duplicating the parent process and is available only on Unix-based systems. The "multiprocessing" module provides a high-level and portable way to create processes with separate memory spaces and works across different operating systems.

# %% [markdown]
# 19. What is the importance of closing a file in Python?
#
#
#       - Closing a file in Python is important because it frees the computer's resources, makes sure all data is properly saved, prevents file problems, and keeps the program running smoothly.

# %% [markdown]
# 20. What is the difference between file.read() and file.readline() in Python?
#
#    - file.read(): reads the entire file content at once,
#
#    - while file.readline() reads one line at a time.and is more memory-efficient and suitable for large files.

# %% [markdown]
# 21. What is the logging module in Python used for?
#
#
#      - The logging module in Python is used to record messages about a program's execution.It helps developers track events, errors, warnings, and informational messages while the program is running.

# %% [markdown]
# 22.  What is the os module in Python used for in file handling?
#
#
#      - The os module in Python is used for file handling tasks such as creating, deleting, renaming files and directories, checking file existence, and interacting with the operating system environment.

# %% [markdown]
# 24.  How do you raise an exception manually in Python0
#
#      - An exception can be raised manually in Python using the raise keyword. It is used to generate an exception intentionally when a specific condition occurs, allowing the programmer to handle errors effectively.

# %% [markdown]
# # Practical Questions

# %%
# Q1. How can you open a file for writing in Python and write a string to it


with open("example.txt", "w") as file:
    file.write("Hello, World")
    file.write("I am Rahul")
    file.write("I am learning python")
    file.write("I am from Bihar")

# %%
# Q2. Write a Python program to read the contents of a file and print each line

with open("example.txt", "r") as file:
    for line in file:
        print(line)
# Out:
# Hello, World

# %%
# Q3.  How would you handle a case where the file doesn't exist while trying to open it for reading

try:
    with open("non_existent_file.txt", "r") as file:
        content = file.read()
        print(content)
except FileNotFoundError:
    print("File not found")
# Out:
# File not found

# %%
# Q4.  Write a Python script that reads from one file and writes its content to another file

with open("example.txt", "r") as source_file:
    content = source_file.read()

with open("destination.txt", "w") as destination_file:
    destination_file.write(content)

# %%
# Q5. How would you catch and handle division by zero error in Python

try:
    result = 10 / 0
except ZeroDivisionError:
    print("Error: Division by zero")
# Out:
# Error: Division by zero

# %%
#Q6. Write a Python program that logs an error message to a log file when a division by zero exception occurs

import logging

logging.basicConfig(filename="error.log", level=logging.ERROR ,format="%(asctime)s - %(levelname)s - %(message)s")

try:
    a=int(input("enter a number"))
    b=int(input("enter a number"))
    result=a/b
    print("Result:",result)
except ZeroDivisionError:
    logging.error("Error: Division by zero")
# Out:
# enter a number3
# enter a number0
# ERROR:root:Error: Division by zero

# %%
#Q7. How do you log information at different levels (INFO, ERROR, WARNING) in Python using the logging module

import logging

logging.basicConfig(level=logging.INFO ,format="%(levelname)s:%(message)s")

logging.info("This is an info message")
logging.warning("This is a warning message")
logging.error("This is an error message")
# Out:
# WARNING:root:This is a warning message
# ERROR:root:This is an error message

# %%
# Q8.  Write a program to handle a file opening error using exception handling


try:
    with open("data11.txt", "r") as file:
        content = file.read()
    print(content)
except FileNotFoundError:
    print("File not found")
# Out:
# File not found

# %%
# Q9.  How can you read a file line by line and store its content in a list in Python

with open("example.txt", "r") as file:
    lines = []
    for line in file:
        lines.append(line.strip())

print(lines)
# Out:
# ['Hello, WorldI am RahulI am learning pythonI am from Bihar']

# %%
# Q10.  How can you append data to an existing file in Python

with open("example.txt", "a") as file:
    file.write("\nThis is a new line")

# %%
# Q11. Write a Python program that uses a try-except block to handle an error when attempting to access a dictionary key that doesn't exist

my_dict={
    "name":"Rahul",
    "age" : 23,
    "course" : " python"
    }


try:
    print(my_dict["city"])

except KeyError:
    print("Error: Key not found in dictionary")
# Out:
# Error: Key not found in dictionary

# %%
# Q12.  Write a program that demonstrates using multiple except blocks to handle different types of exceptions

try:
    a=int(input("enter a number"))
    b=int(input("enter a number"))
    result=a/b
    print("Result:",result)

except ZeroDivisionError:
    print("Error: Division by zero")

except ValueError:
    print("Error: Invalid input")

except Exception:
    print("Some Other problem ")
# Out:
# enter a number6
# enter a numberrahul
# Error: Invalid input

# %%
# Q13.  How would you check if a file exists before attempting to read it in Python
import os

if os.path.exists("data.txt"):
    with open("data.txt", "r") as file:
        print(file.read())
else:
    print("File does not exist")
# Out:
# File does not exist

# %%
#Q14. Write a program that uses the logging module to log both informational and error messages

import logging

logging.basicConfig(level=logging.INFO ,format="%(levelname)s:%(message)s")

logging.info("program started")

try :
    a=int(input("enter a number"))
    b=int(input("enter a number"))
    result=a/b
    print("Result:",result)
except ZeroDivisionError:
  logging.error("Error: Division by zero")
  print("Error: Division by zero")

logging.info("program ended")
# Out:
# enter a number6
# enter a number0
# ERROR:root:Error: Division by zero
# Error: Division by zero

# %%
# Q15. Write a Python program that prints the content of a file and handles the case when the file is empty

try:
    with open("example.txt", "r") as file:
        content = file.read()

        if not content:
            print("File is empty")
        else:
            print(content)
            print("File content printed successfully")
except FileNotFoundError:
    print("File not found")
# Out:
# Hello, WorldI am RahulI am learning pythonI am from Bihar
# This is a new line
# File content printed successfully

# %%
# Q17.Write a Python program to create and write a list of numbers to a file, one number per line

numbers = [1, 2, 3, 4, 5]

with open("numbers.txt", "w") as file:
    for number in numbers:
        file.write(str(number) + "\n")

# %%
#Q19.  Write a program that handles both IndexError and KeyError using a try-except block

my_list = [10,20,30]
my_dict = {"name": "Rahul", "age": 23}

try:
    print(my_list[3])
except IndexError:
    print("Error: Index out of range")

try:
    print(my_dict["city"])
except KeyError:
    print("Error: Key not found in dictionary")
# Out:
# Error: Index out of range
# Error: Key not found in dictionary

# %%
#Q22.  How can you check if a file is empty before attempting to read its contents

import os

if os.path.exists("example.txt") and os.path.getsize("example.txt") == 0:
    print("File is empty")
else:
    with open("example.txt", "r") as file:
        content = file.read()
        print(content)
# Out:
# Hello, WorldI am RahulI am learning pythonI am from Bihar
# This is a new line
