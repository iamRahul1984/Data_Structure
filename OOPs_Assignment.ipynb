# %% [markdown]
# # Theory Questions

# %% [markdown]
# 1.  What is Object-Oriented Programming (OOP)?
#
#      - The Object-Oriented Programming is a programming paradigm. it is used when we have to solve the real life problems .oops language can be written using classes and objects

# %% [markdown]
# 2. What is a class in OOP?
#
#     - a class in python is a blueprint or the templete used to create objects . the class consists variables and methods . creating a class or classes do not take memory .
#
#      - ex: class students:
#                 pass

# %% [markdown]
# 3. What is an object in OOP?
#
#     - an object in oop is a real instance of a class . it represents a real world entity and is used to access the variable data and methods which is defined in a class with the help of class we can make many objects . creating an object can occupies some memory
#
#       - example of an objects
#
#           - s1 = Student() so here s1 is an object name aand student is a class

# %% [markdown]
# 4. What is the difference between abstraction and encapsulation?
#
#   - abstraction means hiding implementation details means hiding internal details and show only important features
#
#    - abstration is like driving a car without knowing its engine details
#
#    - encapsulation means wrapping or binding the data and methods together into a single unit and restrict from direct access to some part of an object . it is mainly focus on to protect the data and improves data security

# %% [markdown]
# 5.  What are dunder methods in Python?
#
#    - dunder methods are specials methods in a python whose name start and end with double underscores (__). they are also known as magic methods. it has a bulit in functions and operators
#
#      -  example is (  __init__  ) or __add__

# %% [markdown]
# 6.  Explain the concept of inheritance in OOP?
#
#      - inheritance is an oop concept in which a class is acquires the properties of another class is called inheritance
#
#      - in simple example like when a granpa transfer his property to a father then the father transfer the same property to a son
#
#       - granpa-->father-->son/child
#
#
#       - the main class or the root class is called the parent class or base class and the class that receives the data is called the child class or derived class
#
#       - we use the inheritance in the oops because to resuability of code and to reduce the code duplication
#
#
#       - there are many types of inheritance
#
#          - single inheritance - one parent and one child
#
#          - multiple inheritance - one child clas but multiple parents class
#
#          - multilevel inhertance - granpa --> father --> child
#
#          - hierarchical inheritance - it is like a granpa and then many parents classes and then many child class just like how in an it office first is ceo after MD and then team leader and them employees

# %% [markdown]
# 7.  What is polymorphism in OOP?
#
#   - polymorphism comes from two greek letters poly means 'many' and morph means 'forms' . in OOPs , polymorphism allows the same methods name or operation to behave differently depending on the object when it used . this helps in writting flexible , reusable and easy tp maintain
#
#    - in polymorphism there should be a same method name but with different types of parameters

# %% [markdown]
# 8.  How is encapsulation achieved in Python?
#
#     - using access modifiers we can achieved encapsulation
#
#      - a. public members - it can be access from anywhere , can be accessed directly : obj.name
#
#      - b. protected members - using single _ underscore before the variable or methods . it can be access with in the class and its subclass
#
#      - c. private members - using __ diuble undersocre before variable or methods . it cannot be access directly can be using obj__age
#
#      - there are also using getter and setter methods to achieved encapsulation ..

# %% [markdown]
# 9.  What is a constructor in Python?
#
#    - a constructor in python is a special method that is automatically called when an object of a class is created . its main purpose is to initalise the data member(variable) of the class
#
#    - In python, the constructor method is named __init__()
#
#
#
# ```
# # example of a constructor
#
# class student:
#     def __init__(self,name)
#         self.name=name
#
#  s1= student("Rahul")
# ```

# %% [markdown]
# 10.  What are class and static methods in Python?
#
#    -  a class methods works with the class itself not with individual objects
#
#    - uses @classmethod and first parameter will be cls
#
#    - a static method is just a normal function inside a class
#
#    - uses @staticmethod and there is no self or cls

# %% [markdown]
# 11.  What is method overloading in Python?
#
#    - method overloading in python means defining the multiple methods with same name but with different parameters
#
#
#
# ```
# # method overloading
# class demo:
#   def add(self,a,b,c=0)
#       return a+b+c+d
#
# obj =Demo()
# print(obj.add(2,3))
# print(obj.add(2,3,7))
#
# ```
#
#    - python does not support overloading and is considered the last function

# %% [markdown]
# 12. What is method overriding in OOP?
#
#     - when we define a method in a child class and same method already in the parent class so in that case the pthon interpreter determines which to call at runtime based on actual object is being referred to
#
#     - you can always override your parent class methods and the reason is if you want special functionality in your child class
#
# ```
# # method overriding
#
# class parent:
#     def mymethod(self):
#        print("Callinf the parent ")
#
# class child(parent):
#    def mymethod(self):
#        print("Calling child ")
#
# c1=child()
# c.mymethod()
# ```
#   -  it will execute the child class mymethod that is called method overriding

# %% [markdown]
# 13. What is a property decorator in Python ?
#
#    -

# %% [markdown]
# 14. Why is polymorphism important in OOP?
#
#     - one name and many works - same methods name does different jobs for example if we create area method for rectangle ,circle and cube all the methods name is same but the working of all the methods are different

# %% [markdown]
# 15.  What is an abstract class in Python?
#
#
#    - an abstrct class in python is a class that cannot be used to create objects. it is used as a base class for other classes . it contains abstract methods  which are methods without implementation. these methods must be implemeted by the child classes. abstract classes are used to hide implementation details and show only essential features
#
#
# ```
# # abstract class
#
# from abc import ABC,abstractmethod
#
# class ClassName(ABC):
#
#    @abstractmethod
#    def method_name(self):
#        pass
# ```
#
#   -  ABC - makes the class abstract
#   - abstractmethod- declares the abstract method
#   - pass - no any value

# %% [markdown]
# 16. What are the advantages of OOP?
#
#     -  Advantages of OOPs
#
#        - 1. code resuability - oops contains the inheritance that is allow us to reuse the codes
#
#        - 2. data security - using encapsulation we can protect our data inside a class and access it throughmethods
#
#        - 3.  programs are divided into small parts (classes and objects) which make them easy to manage
#
#        - 4. easy maintenance -
#
#        - 5. oops is used to solve the real world problems using classes and objects

# %% [markdown]
# 17.  What is the difference between a class variable and an instance variable?
#
#    - a class variable is shared by all objects of a class and is defined inside a class . Change in a class variable affect all objects
#
#    - an instance variable is unique to each object and is defined inside the constructor(__init__) . Change in an instance variable affect only that specific object

# %% [markdown]
# 18.  What is multiple inheritance in Python?
#
#    - multiple inheritance in python where a single class inherits properties and methods from one or more than one parent class . this allows a child class to reuse the code from multiple classes
#
#    - syntax
#
#
#
# ```
# # multiple inheritance
#
# class A:
#    def method1(self):
#         print("this is parent class1")
#
# class B:
#    def method2(self):
#       print("this is parent class2")
#
# class C(A,B):
#    def method3(self):
#         print("this is child class")
# ```

# %% [markdown]
# 19.  Explain the purpose of ‘’__str__’ and ‘__repr__’ ‘ methods in Python?
#
#
#    - __str__()
# This method returns a readable, user-friendly string representation of an object. It is called when we use print() on an object.
#
#   - __repr__()
# This method returns an official and detailed string representation of an object. It is mainly used for debugging and is called when the object is shown in the interpreter.

# %% [markdown]
# 20.  What is the significance of the ‘super()’ function in Python?
#
#    - the super() function is used to call the method or constructor of a parent class from a child class . it helps in code reuse and avoids writting the parent class name directly
#
# ```
# # super class
# class Parent:
#    def __init__(self):
#       print("Parent class")
#
# class Child(Parent):
#     def __init__(self):
#     super().__init__()  # call the parent class
#     print("Child constructor")
#
# obj=Child()
#
# ```

# %% [markdown]
# 21. What is the significance of the __del__ method in Python?
#
#    - the __del__ method is used to when an object is about to destroyed.
#
#    - it is mainly used to free the memory
#
#    - it is work like destructor in python
#
#    - it is called automatically by python's garbage collector.

# %% [markdown]
# 22. What is the difference between @staticmethod and @classmethod in Python?
#
#    - a static method is a method that does not use the object self or the class cls. it behave like a normal function
#
#
#
# ```
# # Staticmethod
#
# class Calc:
#
#   @staticmethod
#   def add(a,b):
#       return a+b
#
# print(Calc.add(4,7))
#
# ```
#
#   -   a class method is a method that uses the class (cls) instead of the object
#
#
#
# ```
# # class method
#
# class Math:
#     x = 10
#
#     @classmethod
#     def change(cls):
#         cls.x = 20
#
# print(Math.x)   # 10
# Test.change()
# print(Math.x)   # 20
#
#
# ```

# %% [markdown]
# 23. How does polymorphism work in Python with inheritance?
#
#
#    - in python with inheritance polymoripshm mainly works through method overriding
#
#
#
# ```
# # polymorphism with inheritance
# class Animal:
#      def sound(self):
#         print("animal make sound")
#
# class Dog(Animal):
#      def sound(self):
#         print("Dog barks")
#
# class Cat(Animal):
#      def sound(self):
#         print("cat meow")
#
#
# a1=Dog()
# a2=Cat()
#
# a1.sound()
# a2.sound()
#
#
# ```
#
#    - so in the above code there are 3 methods name sound with the same name but with different functionality

# %% [markdown]
# 24. What is method chaining in Python OOP?
#
#      -  method chaining in python oops means calling the multiple methods on the same object in a single line one after another
#
#      - it is used to avoid the repeating the object name again and again
#
#
#
#
# ```
# # method channing
#
# class Demo:
#     def first(self):
#         print("First method")
#         return self
#
#     def second(self):
#         print("Second method")
#         return self
#
#     def third(self):
#         print("Third method")
#
# d = Demo()
# d.first().second().third()
#
#
# ```

# %% [markdown]
# 25.  What is the purpose of the __call__ method in Python?
#
#      - the __call__ method allows an object to be called like a function
#
#      - when we use parenthesis() on an object , python automatically calls its __call__ method
#
# ```
# # __call__ method
#
# class Demo:
#    def __call__(self)
#        print("Object is called like a function")
#
# d= Demo()
# d()    # calls __call__ method
# ```

# %% [markdown]
# # Practical Questions

# %%
# question 1. . Create a parent class Animal with a method speak() that prints a generic message.
#Create a child class Dog that overrides the speak() method to print "Bark!".

class Animal:
  def speak(self):
    print("Animal makes a sound")


class Dog(Animal):
  def speak(self):
    print("Bark")


obj=Dog()
obj.speak()
# Out:
# Bark

# %%
# Q2. Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle
#from it and implement the area() method in both.


from abc import ABC,abstractmethod

class Shape(ABC):
  @abstractmethod
  def area(self):
    pass


class Circle(Shape):
  def area(self,r):
    return 3.14*r*r


class Rectangle(Shape):
  def area(self,l,b):
    return l*b

c=Circle()
print(c.area(5))

r=Rectangle()
print(r.area(4,5))
# Out:
# 78.5
# 20

# %%
# Q3.  Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car
#and further derive a class ElectricCar that adds a battery attribute

class Vehicle:
  def __init__(self,type):
    self.type=type

class Car(Vehicle):
  def __init__(self,type,brand):
    super().__init__(type)
    self.brand=brand


class ElectricCar(Car):
  def __init__(self,type,brand,battery):
    super().__init__(type,brand)
    self.battery=battery

e1=ElectricCar("Electric","Tesla","100 kwh")
print(e1.type)
print(e1.brand)
# Out:
# Electric
# Tesla

# %%
# Q4. Demonstrate polymorphism by creating a base class Bird with a method fly(). Create two derived classes Sparrow and Penguin that override the fly() method.

class Bird:
  def fly(self):
    print("Bird can fly")

class Sparrow(Bird):
  def fly(self):
    print("sparrow can fly")

class Penguin(Bird):
  def fly(self):
    print("Penguin cannot fly")

b1=Sparrow()
b2=Penguin()

b1.fly()
b2.fly()
# Out:
# sparrow can fly
# Penguin cannot fly

# %%
# Q5.  Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes balance and methods to deposit, withdraw, and check balance

class BankAccount:
  def __init__(self,balance=0):
    self.__balance=balance

  def deposit(self,amount):
    self.__balance+=amount

  def withdraw(self,amount):
    self.__balance-=amount

  def check_balance(self):
    return self.__balance


acc1 = BankAccount()
acc1.deposit(1000)
print(f"{acc1.check_balance()} is deposited in your account")
acc1.withdraw(500)
print(f"{acc1.check_balance()} is withdrawl from your account")
print(f"{acc1.check_balance()} is remeaning balance in your account")
# Out:
# 1000 is deposited in your account
# 500 is withdrawl from your account
# 500 is remeaning balance in your account

# %%
# Q6. Demonstrate runtime polymorphism using a method play() in a base class Instrument. Derive classes Guitar and Piano that implement their own version of play().

class Instrument:
  def play(self):
    print("Instrument is playing")

class Guitar(Instrument):
  def play(self):
    print("Guitar is playing")

class Piano(Instrument):
  def play(self):
    print("Piano is playing")

i1=Guitar()
i2=Piano()

i1.play()
i2.play()
# Out:
# Guitar is playing
# Piano is playing

# %%
# Q7.  Create a class MathOperations with a class method add_numbers() to add two numbers and a static method subtract_numbers() to subtract two numbers.

class MathOperations:

  @classmethod
  def add_numbers(cls,a,b):
    return a+b

  @staticmethod
  def sub_numbers(a,b):
    return a-b

print(MathOperations.add_numbers(3,5))
print(MathOperations.sub_numbers(5,3))
# Out:
# 8
# 2

# %%
# Q8.  Implement a class Person with a class method to count the total number of persons created.

class Person:
  count=0

  def __init__(self):
    Person.count+=1


  @classmethod
  def total_persons(cls):
    return cls.count

p1=Person()
p2=Person()
p3=Person()

print(f"total persons:{Person.total_persons()}")
# Out:
# total persons:3

# %%
# Q9. Write a class Fraction with attributes numerator and denominator. Override the str method to display the fraction as "numerator/denominator".

class Fraction:
  def __init__(self,numerator,denominator):
    self.numerator=numerator
    self.denominator=denominator

  def __str__(self):
    return f"{self.numerator}/{self.denominator}"

f1=Fraction(10,10)
print(f1)
# Out:
# 10/10

# %%
# Q11. Create a class Person with attributes name and age. Add a method greet() that prints "Hello, my name is {name} and I am {age} years old."

class Person:
  def __init__(self,name,age):
    self.name=name
    self.age=age

  def greet(self):
    print(f"hello i am {self.name} and i am {self.age} years old")


p1=Person("Rahul", 23)
p1.greet()
# Out:
# hello i am Rahul and i am 23 years old

# %%
# Q12. Implement a class Student with attributes name and grades. Create a method average_grade() to compute the average of the grades.


class Student:
  def __init__(self,name,grades):
    self.name=name
    self.grades=grades


  def average_grade(self):
    return sum(self.grades)/len(self.grades)


s1=Student("Rahul",[70,50,45])
print(s1.name)
print(s1.average_grade())
# Out:
# Rahul
# 55.0

# %%
# Q13.  Create a class Rectangle with methods set_dimensions() to set the dimensions and area() to calculate the area.

class Rectangle:
  def set_dimensions(self,length,width):
    self.length=length
    self.width=width


  def area(self):
    return self.length*self.width


r1=Rectangle()
r1.set_dimensions(10,20)
print(f"the area of rectangle is:{r1.area()}")
# Out:
# the area of rectangle is:200

# %%
# Q14. Create a class Employee with a method calculate_salary() that computes the salary based on hours worked and hourly rate. Create a derived class Manager that adds a bonus to the salary.

class Employee:
  def calculate_salary(self,hours,rate):
    return hours*rate


class Manager(Employee):
  def calculate_salary(self,hours,rate):
    return super().calculate_salary(hours,rate)+1000


m1=Manager()
print(f"Total Salary include Bonus:{m1.calculate_salary(5,500)}")
# Out:
# Total Salary include Bonus:3500

# %%
# Q15. Create a class Product with attributes name, price, and quantity. Implement a method total_price() that calculates the total price of the product.

class Product:
  def __init__(self,name,price,quantity):
    self.name=name
    self.price=price
    self.quantity=quantity

  def total_price(self):
    return self.price*self.quantity


p1=Product("Mobile",10000,2)
print(f"Total price of {p1.quantity} {p1.name} is {p1.total_price()}")
# Out:
# Total price of 2 Mobile is 20000

# %%
# Q16. Create a class Animal with an abstract method sound(). Create two derived classes Cow and Sheep that implement the sound() method.

from abc import ABC,abstractmethod


class Animal(ABC):
  @abstractmethod
  def sound(self):
    pass


class Cow(Animal):
  def sound(self):
    print("Moo")

class Sheep(Animal):
  def sound(self):
    print("Baa")

c=Cow()
c.sound()

s=Sheep()
s.sound()
# Out:
# Moo
# Baa

# %%
# Q17. Create a class Book with attributes title, author, and year_published. Add a method get_book_info() that returns a formatted string with the book's details.

class Book:
  def __init__(self,title,author,year):
    self.title=title
    self.author=author
    self.year_published=year


  def get_book_info(self):
    return f"Title:{self.title}\nAuthor:{self.author}\nYear:{self.year_published}"


b1=Book("Python","Rahul",1999)
print(b1.get_book_info())
# Out:
# Title:Python
# Author:Rahul
# Year:1999

# %%
# Q18. Create a class House with attributes address and price. Create a derived class Mansion that adds an attribute number_of_rooms.

class House:
  def __init__(self,address,price):
    self.address=address
    self.price=price


class Mansion(House):
  def __init__(self,address,price,number_of_rooms):
    super().__init__(address,price)
    self.number_of_rooms=number_of_rooms


m1=Mansion("Mumbai",1000000,4)

print("Address:",m1.address)
print("Price:",m1.price)
print("No_of_rooms:",m1.number_of_rooms)
# Out:
# Address: Mumbai
# Price: 1000000
# No_of_rooms: 4
